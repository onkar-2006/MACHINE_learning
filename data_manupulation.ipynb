# %%
import numpy as np
import pandas as pd

# %%
#numpy as pandas rivision

#to load the data pandas read fuction is used
data =pd.read_csv("data name")

#to check the size
data.shape()

#to ckeck how many value in the data
data.value_counts()

#to check even the any missing value is present or not
data.isnull().sum

#to drop the null value
data.dropna()

#to check the data max value min value and the avg
data.describe()

#to plot a figure
data.plot("hist")

#to rename the perticular column the data
data.rename()

#to convert the catogorical values in the coded values

data.get_dummies()

#to to get the data in the series
pd.Series()

#to make the value in array
np.array()

#to create the dataframe
pd.DataFrame()

#to see how many col in the dataset
data.columns

#to see how many keys in the dataset
data.keys

#to taken an index of the data
data.index()

#to taken an perticular range of the column
data.iloc["coumn range"]
# by this u can split the data into x and y

#to apply any condition on the data
data[data["name of col"]]

#to ckeck the given value is present in the dataset
data.isin()

#to recognze the not empty value
data.notna()

#to check how many values are non zero
data.notna().sum()

#if u want to  replace nan  value with the perticular value
data.fillna("what u want to replace")

#to take all the information of the data used
data.info()

#to see the intial value of the data
data.head()

#to see the last value of the data
data.tail()

#if u wnat to return the data as numpy array
data.values

#to see the size of the dataset
data.size()

#to see the unique value of the dataset
data.nuinque()

#to see all the unique values

data.unique()

#to sort the dataset values
data.sort_values(ascending=False)
data.sort_values(ascending=True)

#u can also thake the min max and  avg value using the fuction
data.max()
data.min()
data.avg()

#to check the standard deviation of the dataset
data.std()

#to combine the dataframe
data.concat
